# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('project3.sqlite')

# %%
df = pd.read_csv("Resources/tmdb_5000_movies_TF.csv")
df
# Out:
#          budget                                             genres      id  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
# ...         ...                                                ...     ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...    9367
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...   72766
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...  231617
# 4801          0                                                 []  126186
# 4802          0                [{"id": 99, "name": "Documentary"}]   25975
#
# ...

# %%
column_names = list(df.columns.values)
column_names
# Out:
# ['budget',
#  'genres',
#  'id',
#  'production_countries',
#  'release_date',
#  'revenue',
#  'runtime',
#  'title',
#  'vote_average',
#  'vote_count',
#  'Country - Afghanistan',
#  'Country - Algeria',
#  'Country - Angola',
#  'Country - Argentina',
#  'Country - Aruba',
#  'Country - Australia',
#  'Country - Austria',
#  'Country - Belgium',
#  'Country - Bhutan',
#  'Country - Bolivia',
#  'Country - Bosnia and Herzegovina',
#  'Country - Brazil',
#  'Country - Bulgaria',
#  'Country - Cambodia',
#  'Country - Cameroon',
#  'Country - Canada',
#  'Country - Chile',
#  'Country - China',
#  'Country - Colombia',
#  'Country - Cyprus',
#  'Country - Czech Republic',
#  'Country - Denmark',
#  'Country - Dominica',
#  'Country - Dominican Republic',
#  'Country - Ecuador',
#  'Country - Egypt',
#  'Country - Fiji',
#  'Country - Finland',
#  'Country - France',
#  'Country - Germany',
#  'Country - Greece',
#  'Country - Guadaloupe',
#  'Country - Guyana',
# ...

# %%
column_names_df = pd.DataFrame (column_names,  columns = ['genres'])
column_names_df
# Out:
#                    genres
# 0                  budget
# 1                  genres
# 2                      id
# 3    production_countries
# 4            release_date
# ..                    ...
# 112       Genre - Mystery
# 113         Genre - Music
# 114      Genre - TV Movie
# 115       Genre - Foreign
# 116   Genre - Documentary
#
# [117 rows x 1 columns]

# %%
genres_df = column_names_df[97:117]
genres_df
# Out:
#                       genres
# 97            Genre - Action
# 98             Genre - Crime
# 99           Genre - Fantasy
# 100        Genre - Adventure
# 101           Genre - Family
# 102            Genre - Drama
# 103  Genre - Science Fiction
# 104         Genre - Thriller
# 105           Genre - Comedy
# 106        Genre - Animation
# 107          Genre - Romance
# 108          Genre - Western
# 109           Genre - Horror
# 110          Genre - History
# 111              Genre - War
# 112          Genre - Mystery
# 113            Genre - Music
# 114         Genre - TV Movie
# 115          Genre - Foreign
# 116      Genre - Documentary

# %%
genres_df['genres'] = genres_df['genres'].str[8:]
genres_df
# Out:
# /var/folders/0p/153rzb85259_hj2vtznb45r00000gn/T/ipykernel_4319/3531103274.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genres_df['genres'] = genres_df['genres'].str[8:]
#               genres
# 97            Action
# 98             Crime
# 99           Fantasy
# 100        Adventure
# 101           Family
# 102            Drama
# 103  Science Fiction
# 104         Thriller
# 105           Comedy
# 106        Animation
# 107          Romance
# 108          Western
# 109           Horror
# 110          History
# 111              War
# 112          Mystery
# 113            Music
# 114         TV Movie
# 115          Foreign
# 116      Documentary

# %%
genres_df
# Out:
#               genres
# 97            Action
# 98             Crime
# 99           Fantasy
# 100        Adventure
# 101           Family
# 102            Drama
# 103  Science Fiction
# 104         Thriller
# 105           Comedy
# 106        Animation
# 107          Romance
# 108          Western
# 109           Horror
# 110          History
# 111              War
# 112          Mystery
# 113            Music
# 114         TV Movie
# 115          Foreign
# 116      Documentary
